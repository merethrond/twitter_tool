# %% [markdown]
# #### Authorization procedure

# %%
import tweepy

"""
Note: The Credentials(key) are to be stored in a file called access_keys.py and stored in the current folder.
I am not pushing the credentials due to security reasons.
"""

from access_keys import *

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# #### tweeting and destroying a tweet

# %%
tweet = api.update_status("hello world. It is another good day.")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# /anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x104487cf8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/update.json?status=hello+world.+It+is+another+good+day. (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x104487cf8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/update.json?status=hello+world.+It+is+another+good+day. (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x104487cf8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-12-08b2340d5d57> in <module>()
# ----> 1 tweet = api.update_status("hello world. It is another good day.")
#
# /anaconda3/lib/python3.6/site-packages/tweepy/api.py in update_status(self, *args, **kwargs)
#     192             allowed_param=['status', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'auto_populate_reply_metadata', 'lat', 'long', 'source', 'place_id', 'display_coordinates'],
#     193             require_auth=True
# --> 194         )(post_data=post_data, *args, **kwargs)
#     195
#     196     def media_upload(self, filename, *args, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# /anaconda3/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/update.json?status=hello+world.+It+is+another+good+day. (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x104487cf8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
tweet.id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ea7d34a1477d> in <module>()
# ----> 1 tweet.id
#
# NameError: name 'tweet' is not defined

# %%
deleted_tweet = api.destroy_status(tweet.id)

# %%
deleted_tweet.created_at
# Out:
# datetime.datetime(2018, 6, 29, 11, 16, 53)

# %% [markdown]
# #### printing followers count of all the friends(the people I am following)

# %%
friends =  api.friends()

# %%
for friend in tweepy.Cursor(api.friends).items():
    print(friend.name, friend.followers_count, sep = ' - ')
# Out:
# Virat Kohli - 25687852
# Suresh Raina - 14781790
# Sachin Tendulkar - 26617845
# Virender Sehwag - 17585163

# %% [markdown]
# #### Relation between ids of tweets and retweets

# %%
retweeted_tweet = api.retweet(tweet.id)

# %%
unretweeted_tweet = api.unretweet(retweeted_tweet.id)

# %%
unretweeted_tweet == tweet
# Out:
# True

# %%
retweeted_tweet == unretweeted_tweet
# Out:
# False

# %%
retweeted_tweet == tweet
# Out:
# False

# %% [markdown]
# #### Get information about a specific twitter user(Change the screen name in the line below to get info of a different user)

# %%
user = api.get_user("Ayushxx7")

# %%
user.statuses_count
# Out:
# 2143

# %%
user.favourites_count
# Out:
# 15

# %%
user.name
# Out:
# 'Ayush Mandowara'

# %%
user.lang
# Out:
# 'en'

# %%
user.location
# Out:
# 'New Delhi, India'

# %%
user.followers_count
# Out:
# 65

# %%
user.friends_count
# Out:
# 78

# %%
'''
Note : Please run these two lines only if the number of followers(and friends respectively) is reasonably low
Change the count limits in the assert statements as needed.
'''
# Printing the names and follower count of user's followers
assert user.followers_count <= 100
assert user.followers_count > 0
print("follower name", "Number of followers", sep = ' - ')
for follower in user.followers():
    print(follower.name, follower.followers_count, sep = ' - ')
# Out:
# follower name - Number of followers
# Tobias Sippl - 6906
# The Malliard Report - 89835
# Klick Invite - 1
# Shubham Jain - 1
# Akiraov - 20
# Aditya Mathur - 9
# Promit Chakraborty - 29
# Ram Kishore - 16
# Vinod Kumar - 16
# Prashant Borda - 200
# Kritika - 6
# Ghanshyam Pandey - 19
# Ayushi Khurana - 3
# Neeraj Jain - 3
# 2TRILL - 4904
# Young Lit Hippies - 38094
# suraj kumar - 38
# Ivan B George - 18
# Raju Mandovara - 4
# Inder Pal Singh - 2

# %%
# Printing the names and follower count of user's friends
assert user.friends_count <= 100 
assert user.friends_count > 0
print("friend's screen name", "Number of followers", sep = ' - ')
for friend in user.friends():
    print(friend.screen_name, friend.followers_count, sep = ' - ' )
# Out:
# friend's screen name - Number of followers
# TheLastPeg - 8924
# KyaUkhaadLega - 301033
# HaramiParindey - 73106
# fjamie013 - 1444448
# prakmandovara - 39
# Saurabh_Chugh01 - 12
# sagnik12roy - 3
# SankeKoli - 9
# Shubham78100 - 11
# Shivam995343 - 245
# aakash95bansal - 32
# Deadshot1070521 - 9
# Adityakoli0010 - 49
# sudarshanshekh3 - 2
# Nitesh12162221 - 12
# pulkitkkr0 - 27
# iamthedevil014 - 2
# bymridul - 58
# Pratyasharma - 8
# SudhirMangla1 - 18

# %% [markdown]
# Remaining number of API requests available to the requesting user before the API limit is reached for the current hour.

# %%
rate_limits = api.rate_limit_status()['resources']

# %%
#This is a JSON objects and is stored in the variable rate_limits as a dictionary.
rate_limits
# Out:
# {'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1530862239},
#   '/lists/subscribers/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1530862239},
#   '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1530862239},
#   '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1530862239},
#   '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1530862239}},
#  'application': {'/application/rate_limit_status': {'limit': 180,
#    'remaining': 179,
#    'reset': 1530862239}},
#  'mutes': {'/mutes/users/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239}},
#  'friendships': {'/friendships/outgoing': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1530862239},
#   '/friendships/no_retweets/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/friendships/incoming': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1530862239}},
#  'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1530862239}},
#  'auth': {'/auth/csrf_token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239}},
#  'blocks': {'/blocks/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'geo': {'/geo/similar_places': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1530862239},
#   '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'users': {'/users/report_spam': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/users/contributors/pending': {'limit': 2000,
#    'remaining': 2000,
#    'reset': 1530862239},
#   '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1530862239},
#   '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1530862239},
#   '/users/suggestions/:slug': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/users/contributees/pending': {'limit': 200,
#    'remaining': 200,
#    'reset': 1530862239},
#   '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/users/profile_banner': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/users/suggestions/:slug/members': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1530862239},
#   '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'followers': {'/followers/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'collections': {'/collections/list': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239},
#   '/collections/entries': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239},
#   '/collections/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239}},
#  'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/statuses/retweets_of_me': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/statuses/home_timeline': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1530862239},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 900,
#    'reset': 1530862239},
#   '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/statuses/retweets/:id': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/statuses/mentions_timeline': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1530862239},
#   '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1530862239}},
#  'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/custom_profiles/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239}},
#  'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'contacts': {'/contacts/uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1530862239},
#   '/contacts/addressbook': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/contacts/users_and_uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/contacts/delete/status': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239}},
#  'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/tweet_prompts/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239}},
#  'moments': {'/moments/statuses/update': {'limit': 5,
#    'remaining': 5,
#    'reset': 1530862239},
#   '/moments/permissions': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239}},
#  'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'feedback': {'/feedback/show/:id': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/feedback/events': {'limit': 1000, 'remaining': 1000, 'reset': 1530862239}},
#  'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/business_experience/dashboard_features': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/business_experience/keywords': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/business_experience/dashboard_settings/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/business_experience/dashboard_settings/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239}},
#  'friends': {'/friends/following/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/friends/following/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1530862239},
#   '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1530862239}},
#  'drafts': {'/drafts/statuses/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/drafts/statuses/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/drafts/statuses/ids': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/drafts/statuses/list': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/drafts/statuses/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239},
#   '/drafts/statuses/create': {'limit': 450,
#    'remaining': 450,
#    'reset': 1530862239}},
#  'direct_messages': {'/direct_messages/sent': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/direct_messages/broadcasts/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1530862239},
#   '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239},
#   '/direct_messages/mark_read': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239},
#   '/direct_messages/subscribers/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/direct_messages/sent_and_received': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1530862239},
#   '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1530862239},
#   '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/direct_messages/subscribers/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/direct_messages/broadcasts/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1530862239},
#   '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1530862239},
#   '/direct_messages/subscribers/lists/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/direct_messages/show': {'limit': 300,
#    'remaining': 300,
#    'reset': 1530862239},
#   '/direct_messages/events/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/direct_messages/subscribers/lists/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239},
#   '/direct_messages/events/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239}},
#  'media': {'/media/upload': {'limit': 500,
#    'remaining': 500,
#    'reset': 1530862239}},
#  'traffic': {'/traffic/map': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239}},
#  'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/all/:instance_name/subscriptions': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/direct_messages/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#    'remaining': 500,
#    'reset': 1530862239},
#   '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#    'remaining': 500,
#    'reset': 1530862239},
#   '/account_activity/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1530862239},
#   '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239}},
#  'account': {'/account/login_verification_enrollment': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account/update_profile': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/account/verify_credentials': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'safety': {'/safety/detection_feedback': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1530862239}},
#  'favorites': {'/favorites/list': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239}},
#  'device': {'/device/token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239}},
#  'tweets': {'/tweets/search/:product/:label': {'limit': 1800,
#    'remaining': 1800,
#    'reset': 1530862239},
#   '/tweets/search/:product/:instance/counts': {'limit': 900,
#    'remaining': 900,
#    'reset': 1530862239}},
#  'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/saved_searches/show/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1530862239},
#   '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1530862239}},
#  'search': {'/search/tweets': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239}},
#  'trends': {'/trends/closest': {'limit': 75,
#    'remaining': 75,
#    'reset': 1530862239},
#   '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1530862239},
#   '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1530862239}},
#  'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#    'remaining': 180,
#    'reset': 1530862239}}}

# %% [markdown]
# #### Send direct message to your followers. You cannot send messages to users who are not following you.

# %%
for follower in tweepy.Cursor(api.followers).items():
    api.send_direct_message(follower.screen_name, text = "Hello "+ follower.name +", I hope you are having a good day.")

# %% [markdown]
# #### Like some tweets from your timeline.

# %%
'''
There seems to be no way to unlike the tweet(s). You may have to manually unlike them, in case the need arises.
'''
for tweet in tweepy.Cursor(api.home_timeline).items(1):
    tweet.favorite()

# %% [markdown]
# #### Save the hashtag texts of a given number of tweets in a list. Print out only the unique ones.

# %%
hashtags = []
for tweet in tweepy.Cursor(api.home_timeline).items(50):
    hashtags += [el['text'] for el in [dictionary for dictionary in tweet.entities['hashtags']]]
unique_hashtags = set(hashtags)

# %%
unique_hashtags
# Out:
# {'1983WorldCup',
#  'Adolescence',
#  'CALLFORACTION',
#  'ChampionsTrophy',
#  'DBS',
#  'HCT2018',
#  'HELP',
#  'Hashim',
#  'Hindu',
#  'HumFitToIndiaFit',
#  'HumFitTohIndiaFit',
#  'INDvPAK',
#  'KabaddiMasters',
#  'KitUpChallenge',
#  'NewDelhi',
#  'RDBurman',
#  'RanbirKapoor',
#  'Sanju',
#  'SparkAPurpose',
#  'SportPlayingIndia',
#  'ThanksMom',
#  'myfirstTweet'}

# %% [markdown]
# #### follow people based on keywords

# %%
search_text = "Follow4follow #f4f #follow4follow #follow4Follow #followme"
friends = []
for tweet in tweepy.Cursor(api.search, search_text).items(10):
    print(tweet.text)
    tweet.author.follow()
    friends.append(tweet.author.screen_name)
friends
# Out:
# #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam… https://t.co/yUsG76K1Gm
# RT @KobirMl: #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam #followhim #followal…
# #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam… https://t.co/KLcnDHX5sl
# RT @KobirMl: #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam #followhim #followal…
# #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam… https://t.co/wCcLHBSvp3
# https://t.co/qCY17gJDtZ #teamfollow #TF #teamfollowback #INST #followme #FollowFriday #TAF #GFB #MustFollow… https://t.co/wTVbToYTjd
# ❤
#
# #follow #f4f #followme #TFLers #followforfollow #follow4follow #teamfollowback #followher #followbackteam… https://t.co/oEcsdkOWw3
# #openfollow #teamfollowback #TFB  #followme #ifollowback #sougofollow #90sBabyFollowTrain #Autofollow #instantfollow #F4F #Follow4Follow 2
# #openfollow #teamfollowback #TFB #ff #followme #ifollowback #sougofollow #90sBabyFollowTrain #Autofollow #instantfollow #F4F #Follow4Follow
# Photoshoot
# Photographer-@mukesh_piyush
# #follow #f4f #followme #TFLers #followforfollow #follow4follow… https://t.co/D3qrJKmNca
# ['KobirMl',
#  'LeadFromBack',
#  'KobirMl',
#  'love4ulot',
#  'KobirMl',
#  'MargotOcean',
#  'MNKMusicizer',
#  'BigLucci_',
#  'BigLucci_',
#  'saumyatrips']

# %% [markdown]
# #### to unfollow the ones in the list of friends

# %%
for screen_name in friends:
    api.destroy_friendship(screen_name)

# %% [markdown]
# #### Using Streaming API to filter data and understand its usage.

# %%
# class MyStreamListener(tweepy.StreamListener)
#     def on_status(self, status):
#         print(status.text)
# myStreamListener = MyStreamListener()
# myStream = tweepy.Stream(auth = api.auth, listener= myStreamListener)

# %% [markdown]
# [A blog](http://adilmoujahid.com/posts/2014/07/twitter-analytics/)

# %%
api.retweet(1013717452268584961)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# /anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1044762b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/retweet/1013717452268584961.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1044762b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/retweet/1013717452268584961.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1044762b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-6-024138321457> in <module>()
# ----> 1 api.retweet(1013717452268584961)
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248             return method
#     249         else:
# --> 250             return method.execute()
#     251
#     252     # Set pagination mode
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# /anaconda3/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /anaconda3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/retweet/1013717452268584961.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1044762b0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
#reverting the changes.
for status in api.user_timeline("Ayushxx7"):
    print(status.text)
    api.destroy_favorite(status.id)
# Out:
# I liked a @YouTube video https://t.co/GDS3GazvCz Azadi ( Dub Sharma) Video
# I liked a @YouTube video https://t.co/VlLiliGfjj AIB : Arranged Move In
# I liked a @YouTube video https://t.co/lTAXT2WXNo आंसुओं को रोक नहीं पाएंगे ! Media will not
# I liked a @YouTube video https://t.co/F68EEy3PBV The RoastMasters 8.9.16: Dina Hashem vs. Samantha Ruddy
# trying out #followforfollow #FollowForFollow #f4f #follow4follow #Follow4Follow
# I liked a @YouTube video https://t.co/BkhGoeL2Co Shut Up Ya Kunal - Episode 4 : Journalism &amp; Defamation
# I liked a @YouTube video https://t.co/2roSPkcJ25 Country Main GHAPAGHAP | Viral Fuddu
# I liked a @YouTube video https://t.co/4LT1p66DXG TVF College Admission Qtiyapa | Ek Admission Aisa Bhi
# I liked a @YouTube video https://t.co/WUVfPAeevi The RoastMasters Tournament 8.21.17: Mike Recine vs. Dina Hashem
# I liked a @YouTube video https://t.co/MSf5F98Rdl Shy deadpan girl viciously defeats a big loud guy in a NYC comedy roast battle
# I liked a @YouTube video https://t.co/dwMnvbnBdf T.J. Miller's 100% improvised set from "SET LIST: Standup w/o A Net" on SkyAtlantic
# I liked a @YouTube video https://t.co/zCh73MYmvD BJP IT Cell Insider Interview with Dhruv Rathee
# I liked a @YouTube video https://t.co/LjNvgOYGAe Trashy Sanju &amp; Rain | TRASHY Thursday | Episode 10
# I liked a @YouTube video https://t.co/wWK7shNrgf Weed Smokin' Kids (Stand Up Comedy)
# I liked a @YouTube video https://t.co/cSXdeWM6tf Moksi (DJ-set LIVE @ ADE) | SLAM!
# I liked a @YouTube video https://t.co/qLcVE8Xxyt DIVINE - GULLY GANG - ft. Modi Mashup
# I liked a @YouTube video https://t.co/DAPx9TSJRJ Dame Tu Cosita Mashup | Ft.Sunny Deol | Funny Dancing
# I liked a @YouTube video https://t.co/HHj0CQDmiU Yellow Claw &amp; DJ Snake - Ft. Manoj Tiwari | Bhojpuri Trippy Mashup
# I liked a @YouTube video https://t.co/YWfMBtKfix Ab Dangal Hoga | Modi Fitness Challenge | Modi Dancing Mashup
# I liked a @YouTube video https://t.co/PFmilt7sho Ganja - Ft. Ramdev Baba REMIX! | ssquare x Dipraj Jadhav
